# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#import CSV files into DataFrame Bandas
df1=pd.read_csv('/content/drive/MyDrive/0001Submission/Data/inDataForModels/df_TrainOutFinal.csv')
df2=pd.read_csv('/content/drive/MyDrive/0001Submission/Data/inDataForModels/df_TestOutFinal.csv')

# %%
df1.shape
# Out:
# (496633, 9)

# %%
df1.head(5)
# Out:
#    QuestionId  UserId  Gender   Age  ...  QuizId  SubjectID3  SubjectID4  IsCorrect
# 0       17076   62121       1  13.0  ...    7789        36.0       144.0          1
# 1       17076   52372       0  15.0  ...    2210        36.0       144.0          0
# 2       17076   56036       2  10.0  ...   10345        36.0       144.0          1
# 3       17076   15017       0  15.0  ...    9960        36.0       144.0          1
# 4       17076   83589       0  15.0  ...    2210        36.0       144.0          0
#
# [5 rows x 9 columns]

# %%
df2.shape
# Out:
# (940625, 9)

# %%
df2.head(5)
# Out:
#    QuestionId  UserId  Gender   Age  ...  QuizId  SubjectID3  SubjectID4  IsCorrect
# 0       10856    5518       2  17.0  ...   13180        36.0       224.0          1
# 1       10856  101527       1  15.0  ...   13180        36.0       224.0          1
# 2       10856  107371       2  16.0  ...   13180        36.0       224.0          1
# 3       10856   23837       2  17.0  ...   13180        36.0       224.0          1
# 4       10856  101611       1  16.0  ...   13180        36.0       224.0          0
#
# [5 rows x 9 columns]

# %%
X=df1
y=df2

# %%
from sklearn.svm import SVC
# we create an instance of SVM and fit out data. We do not scale our
# data since we want to plot the support vectors
C = 1.0  # SVM regularization parameter

svc = SVC(kernel='linear', C=C).fit(X, y)
rbf_svc_07 = SVC(kernel='rbf', gamma=0.7, C=C).fit(X, y)
rbf_svc_10 = SVC(kernel='rbf', gamma=10, C=C).fit(X, y)
rbf_svc_100 = SVC(kernel='rbf', gamma=100, C=C).fit(X, y)
poly_svc = SVC(kernel='poly', degree=3, C=C).fit(X, y)
lin_svc = LinearSVC(C=C).fit(X, y)

# %%
# Predicting the test set results   svc kernel='linear'
svc_predict = svc.predict(X_test)
print("accuracy: ",accuracy_score(y_test,svc_predict))
print("f1 score: ",f1_score(y_test,svc_predict))
print("precision: ",precision_score(y_test,svc_predict))
print("recall: ",recall_score(y_test,svc_predict))

# %%
# Predicting the test set results  rbf svc  gamma=0.7
rbf_svc_07_predict = rbf_svc_07.predict(X_test)
print("accuracy: ",accuracy_score(y_test,rbf_svc_07_predict))
print("f1 score: ",f1_score(y_test,rbf_svc_07_predict))
print("precision: ",precision_score(y_test,rbf_svc_07_predict))
print("recall: ",recall_score(y_test,rbf_svc_07_predict))

# %%
# Predicting the test set results  rbf svc  gamma=10
rbf_svc_10_predict = rbf_svc_10.predict(X_test)
print("accuracy: ",accuracy_score(y_test,rbf_svc_10_predict))
print("f1 score: ",f1_score(y_test,rbf_svc_10_predict))
print("precision: ",precision_score(y_test,rbf_svc_10_predict))
print("recall: ",recall_score(y_test,rbf_svc_10_predict))

# %%
# Predicting the test set results  rbf svc  gamma=100
rbf_svc_100_predict = rbf_svc_100.predict(X_test)
print("accuracy: ",accuracy_score(y_test,rbf_svc_100_predict))
print("f1 score: ",f1_score(y_test,rbf_svc_100_predict))
print("precision: ",precision_score(y_test,rbf_svc_100_predict))
print("recall: ",recall_score(y_test,rbf_svc_100_predict))

# %%
# Predicting the test set results   svc kernel='poly'
poly_svc_predict = poly_svc.predict(X_test)
print("accuracy: ",accuracy_score(y_test,poly_svc_predict))
print("f1 score: ",f1_score(y_test,poly_svc_predict))
print("precision: ",precision_score(y_test,poly_svc_predict))
print("recall: ",recall_score(y_test,poly_svc_predict))

# %%
# Predicting the test set results  Linear SVC linear kernel
lin_svc_predict = lin_svc.predict(X_test)
print("accuracy: ",accuracy_score(y_test,lin_svc_predict))
print("f1 score: ",f1_score(y_test,lin_svc_predict))
print("precision: ",precision_score(y_test,lin_svc_predict))
print("recall: ",recall_score(y_test,lin_svc_predict))

# %%
h = .02  # step size in the mesh
# create a mesh to plot in
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

# title for the plots
titles = ['SVC with linear kernel',
          'LinearSVC (linear kernel)',
          'SVC with RBF kernel gamma =0.7',
          'SVC with RBF kernel gamma =10',
          'SVC with RBF kernel gamma =100',
          'SVC with polynomial (degree 3) kernel']


for i, clf in enumerate((svc, lin_svc, rbf_svc_07, rbf_svc_10, rbf_svc_100, poly_svc)):
    # Plot the decision boundary. For that, we will assign a color to each
    # point in the mesh [x_min, x_max]x[y_min, y_max].
    plt.subplot(2, 2, i + 1)
    plt.subplots_adjust(wspace=0.4, hspace=0.4)

    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])

    # Put the result into a color plot
    Z = Z.reshape(xx.shape)
    plt.contourf(xx, yy, Z, cmap=plt.cm.coolwarm, alpha=0.8)

    # Plot also the training points
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.coolwarm)
    plt.xlabel('IsCorrect')
    plt.ylabel('IsCorrect')
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    plt.xticks(())
    plt.yticks(())
    plt.title(titles[i])

plt.show()

# %%
#https://www.analyticsvidhya.com/blog/2017/09/understaing-support-vector-machine-example-code/

# %%
"""

# Fitting the classifier into the Training set
from sklearn.svm import SVC
classifier = SVC(kernel = 'linear', random_state = 0)
classifier.fit(X_train, y_train)


# Predicting the test set results
y_Pred = classifier.predict(X_test)


print(y_Pred)


# Making the Confusion Matrix 
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_Pred)
cm

print("accuracy: ",accuracy_score(y_test,y_Pred))
print("f1 score: ",f1_score(y_test,y_Pred))
print("precision: ",precision_score(y_test,y_Pred))
print("recall: ",recall_score(y_test,y_Pred))





"""
