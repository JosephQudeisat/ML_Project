# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#import CSV files into DataFrame Bandas
#df_TestDatapd.read_csv('/content/drive/MyDrive/Colab Notebooks/ibrahim/Data/df_TrainFinal.csv')
df_TestData=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/ibrahim/Data/df_TestFinal.csv')

# %%
df_TestData.head(5)
# Out:
#    Unnamed: 0  QuestionId  UserId  ...  GroupId  QuizId  SchemeOfWorkId
# 0           0       10856    5518  ...     2143   13180         40960.0
# 1           1       10856   65834  ...     3644   13180         40960.0
# 2           2       10856   32841  ...     7900   13180         40960.0
# 3           3       10856   24996  ...     7331   13180         40960.0
# 4           4       10856   12067  ...     8482   13180         40960.0
#
# [5 rows x 17 columns]

# %%
#convert DateOfBirth to year only
df_TestData["DateOfBirth"]=pd.to_datetime(df_TestData["DateOfBirth"], errors = 'coerce')
df_TestData["DateOfBirth"]=df_TestData.DateOfBirth.dt.year
#df_TestData["DateOfBirth"]=df_TestData["DateOfBirth"].astype(int)
#convert DateAnswered to year only
df_TestData["DateAnswered"]=pd.to_datetime(df_TestData["DateAnswered"], errors = 'coerce')
df_TestData["DateAnswered"]=df_TestData.DateAnswered.dt.year
#df_TestData['DateOfBirth'].mode()
df_TestData["DateOfBirth"].fillna(2007, inplace = True)

# %%
df_TestData['Age']=df_TestData["DateAnswered"]-df_TestData["DateOfBirth"]

# %%
df_TestData.head(5)
# Out:
#    Unnamed: 0  QuestionId  UserId  ...  QuizId  SchemeOfWorkId   Age
# 0           0       10856    5518  ...   13180         40960.0  17.0
# 1           1       10856   65834  ...   13180         40960.0  12.0
# 2           2       10856   32841  ...   13180         40960.0  12.0
# 3           3       10856   24996  ...   13180         40960.0  17.0
# 4           4       10856   12067  ...   13180         40960.0  16.0
#
# [5 rows x 18 columns]

# %%
df_TestData.drop([ 'AnswerId','PremiumPupil','1','4','Confidence','SchemeOfWorkId','DateOfBirth','DateAnswered'], axis = 1,inplace=True)

# %%
df_TestData.drop(df_TestData.columns[0],axis = 1,inplace=True)

# %%
df_TestData
# Out:
#         QuestionId  UserId  IsCorrect  Gender  ...      3  GroupId  QuizId   Age
# 0            10856    5518          1       2  ...  224.0     2143   13180  17.0
# 1            10856   65834          1       0  ...  224.0     3644   13180  12.0
# 2            10856   32841          1       1  ...  224.0     7900   13180  12.0
# 3            10856   24996          1       1  ...  224.0     7331   13180  17.0
# 4            10856   12067          1       1  ...  224.0     8482   13180  16.0
# ...            ...     ...        ...     ...  ...    ...      ...     ...   ...
# 940623       25391   38045          1       1  ...  203.0      879   16811   7.0
# 940624       25391   67516          0       1  ...  203.0     6047   16811   7.0
# 940625        7731   75795          1       0  ...  248.0     2580    7239  13.0
# 940626       11367   63562          1       2  ...  203.0     7133    5968  12.0
# 940627        7631   28515          0       1  ...  247.0     8207    8810  15.0
#
# ...

# %%
df_TestData.isnull().any()
# Out:
# QuestionId    False
# UserId        False
# IsCorrect     False
# Gender        False
# 2             False
# 3              True
# GroupId       False
# QuizId        False
# Age           False
# dtype: bool

# %%
df_TestData['3'] = df_TestData['3'].fillna(0)

# %%
df_TestData.isnull().any()
# Out:
# QuestionId    False
# UserId        False
# IsCorrect     False
# Gender        False
# 2             False
# 3             False
# GroupId       False
# QuizId        False
# Age           False
# dtype: bool

# %%
df_TestData.head(3)
# Out:
#    QuestionId  UserId  IsCorrect  Gender     2      3  GroupId  QuizId   Age
# 0       10856    5518          1       2  36.0  224.0     2143   13180  17.0
# 1       10856   65834          1       0  36.0  224.0     3644   13180  12.0
# 2       10856   32841          1       1  36.0  224.0     7900   13180  12.0

# %%
df_TestData_Temp=df_TestData[['QuestionId','UserId','Gender','Age','GroupId','QuizId','2','3','IsCorrect']]

# %%
df_TestData_Temp.to_csv('/content/drive/MyDrive/Colab Notebooks/ibrahim/Data/df_TestOutFinal.csv',index=False)
